# %%
# Importing librairies

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings 
warnings.filterwarnings('ignore')

# %%
#importing dataset
data=pd.read_csv('insurance_data.csv')
data.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
data.replace('?',np.nan,inplace=True)

# %%
data.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
# check les valeurs nulles 
data.isna().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                  178
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
missing=data.isnull().sum()/len(data) #pourcentage 
missing= missing[missing>0] #pourcentage >0
missing.sort_values(inplace=True) # tri ascendant , inplace=remplacer
missing=missing.to_frame() 
missing.columns=['Null_Count']
missing.index.names=['col_Name']
missing=missing.reset_index()
sns.set(style='whitegrid',color_codes=True)
sns.barplot(x='col_Name',y='Null_Count',data=missing )
plt.xticks(rotation=90)
plt.show()

# %%
#mode()[0] : most frequent value 
data['collision_type']= data['collision_type'].fillna(data['collision_type'].mode()[0])
data['property_damage']= data['property_damage'].fillna(data['property_damage'].mode()[0])
data['police_report_available']= data['police_report_available'].fillna(data['police_report_available'].mode()[0])

# %%
# plt.figure(figsize=(18,15))
# corr = data.corr

# sns.heatmap(data=corr, annot=True, fmt=".2f", cmap='coolwarm')
# plt.show()

# %%
unique =data.nunique().to_frame() #unique values for each column
unique.columns=['Count']
unique.index.names=['ColName']
unique=unique.reset_index()
sns.set(style='whitegrid',color_codes=True)
sns.barplot(x='ColName',y='Count',data=unique)
plt.xticks(rotation=90)
plt.show()

# %%
unique.sort_values(by='Count',ascending=False)
# Out:
#                         ColName  Count
# 2                 policy_number   1000
# 24            incident_location   1000
# 9                   insured_zip    995
# 7         policy_annual_premium    991
# 3              policy_bind_date    951
# 31           total_claim_amount    763
# 34                vehicle_claim    726
# 32                 injury_claim    638
# 33               property_claim    626
# 0            months_as_customer    391
# 16                 capital-loss    354
# 15                capital-gains    338
# 17                incident_date     60
# 1                           age     46
# 36                   auto_model     39
# 25     incident_hour_of_the_day     24
# 37                    auto_year     21
# 13              insured_hobbies     20
# 35                    auto_make     14
# 12           insured_occupation     14
# 8                umbrella_limit     11
# 11      insured_education_level      7
# 23                incident_city      7
# ...

# %%
#drop columns that are not used in our project 
to_drop=['policy_number','policy_bind_date','policy_state','insured_zip','incident_location','incident_date',
         'incident_state','incident_city','insured_hobbies','auto_make','auto_model','auto_year','_c39']
data.drop(to_drop, inplace=True, axis=1)

# %%
data.head()
# Out:
# ColName  months_as_customer  age policy_csl  policy_deductable  \
# 0                       328   48    250/500               1000
# 1                       228   42    250/500               2000
# 2                       134   29    100/300               2000
# 3                       256   41    250/500               2000
# 4                       228   44   500/1000               1000
#
# ColName  policy_annual_premium  umbrella_limit insured_sex  \
# 0                      1406.91               0        MALE
# 1                      1197.22         5000000        MALE
# 2                      1413.14         5000000      FEMALE
# 3                      1415.74         6000000      FEMALE
# 4                      1583.91         6000000        MALE
#
# ColName insured_education_level insured_occupation insured_relationship  ...  \
# 0                            MD       craft-repair              husband  ...
# ...

# %%
# plt.figure(figsize=(18,15))
# corr=data.corr
# mask=np.triu(np.ones_like(corr, dtype=bool))
# sns.heatmap(data=corr,mask=mask,annot=True,fmt='.2g',linewidth=1)

# %%
data.drop(columns=['age','total_claim_amount'], inplace=True , axis=1)

# %%
data.head()
# Out:
# ColName  months_as_customer policy_csl  policy_deductable  \
# 0                       328    250/500               1000
# 1                       228    250/500               2000
# 2                       134    100/300               2000
# 3                       256    250/500               2000
# 4                       228   500/1000               1000
#
# ColName  policy_annual_premium  umbrella_limit insured_sex  \
# 0                      1406.91               0        MALE
# 1                      1197.22         5000000        MALE
# 2                      1413.14         5000000      FEMALE
# 3                      1415.74         6000000      FEMALE
# 4                      1583.91         6000000        MALE
#
# ColName insured_education_level insured_occupation insured_relationship  \
# 0                            MD       craft-repair              husband
# 1                            MD  machine-op-inspct       other-relative
# ...

# %%
#get target and independent features seperated 
X=data.drop('fraud_reported',axis=1)
Y=data['fraud_reported']

# %%
#Convert label columns into numerical by one-encoding
categorical_cols=X.select_dtypes(include=['object'])
categorical_cols=pd.get_dummies(categorical_cols,drop_first=True)
categorical_cols.head()
# Out:
#    policy_csl_250/500  policy_csl_500/1000  insured_sex_MALE  \
# 0                True                False              True
# 1                True                False              True
# 2               False                False             False
# 3                True                False             False
# 4               False                 True              True
#
#    insured_education_level_College  insured_education_level_High School  \
# 0                            False                                False
# 1                            False                                False
# 2                            False                                False
# 3                            False                                False
# 4                            False                                False
#
#    insured_education_level_JD  insured_education_level_MD  \
# 0                       False                        True
# ...

# %%
numerical_col =X.select_dtypes(include=['int64'])
X=pd.concat([numerical_col,categorical_cols],axis=1)

# %%
X.head()
# Out:
#    months_as_customer  policy_deductable  umbrella_limit  capital-gains  \
# 0                 328               1000               0          53300
# 1                 228               2000         5000000              0
# 2                 134               2000         5000000          35100
# 3                 256               2000         6000000          48900
# 4                 228               1000         6000000          66000
#
#    capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# 0             0                         5                            1
# 1             0                         8                            1
# 2             0                         7                            3
# 3        -62400                         5                            1
# 4        -46000                        20                            1
#
#    bodily_injuries  witnesses  injury_claim  ...  \
# 0                1          2          6510  ...
# ...

# %%
#outlier Check 
plt.figure(figsize=(20,15))
plotnumber=1
for col in X.columns:
    if plotnumber <=24:
        ax=plt.subplot(5,5,plotnumber)
        sns.boxenplot(X[col])
        plt.xlabel(col,fontsize=15)

    plotnumber+=1
plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.25)

# %%
X_train.head()
# Out:
#      months_as_customer  policy_deductable  umbrella_limit  capital-gains  \
# 991                 257               1000               0          59400
# 90                  127               2000         5000000              0
# 983                  17               1000               0          32500
# 128                 274               2000               0          40700
# 407                 269                500               0          54800
#
#      capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# 991        -32200                        21                            1
# 90              0                        12                            2
# 983        -80800                         9                            1
# 128        -47300                        22                            1
# 407        -64100                         5                            3
#
#      bodily_injuries  witnesses  injury_claim  ...  \
# ...

# %%
numerical_data=X_train[['months_as_customer','policy_deductable','umbrella_limit',
                        'capital-gains','capital-loss','incident_hour_of_the_day',
                        'number_of_vehicles_involved','bodily_injuries','witnesses',
                        'injury_claim', 'property_claim','vehicle_claim']]

# %%
#standardization 
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_data= scaler.fit_transform(numerical_data)

# %%
scaled_num_df=pd.DataFrame(data=scaled_data,columns=numerical_data.columns, index=X_train.index)
scaled_num_df.head()
# Out:
#      months_as_customer  policy_deductable  umbrella_limit  capital-gains  \
# 991            0.429289          -0.240714       -0.497748       1.252670
# 90            -0.688055           1.393093        1.642798      -0.903843
# 983           -1.633500          -0.240714       -0.497748       0.276068
# 128            0.575404           1.393093       -0.497748       0.573768
# 407            0.532429          -1.057618       -0.497748       1.085668
#
#      capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# 991     -0.194098                  1.352635                    -0.801572
# 90       0.950248                  0.053135                     0.187209
# 983     -1.921280                 -0.380031                    -0.801572
# 128     -0.730733                  1.497024                    -0.801572
# 407     -1.327783                 -0.957587                     1.175991
#
#      bodily_injuries  witnesses  injury_claim  property_claim  vehicle_claim
# ...

# %%
X_train.drop(columns=scaled_num_df.columns,inplace=True)

# %%
X_train=pd.concat([scaled_num_df,X_train],axis=1)

# %%
X_train.head()
# Out:
#      months_as_customer  policy_deductable  umbrella_limit  capital-gains  \
# 991            0.429289          -0.240714       -0.497748       1.252670
# 90            -0.688055           1.393093        1.642798      -0.903843
# 983           -1.633500          -0.240714       -0.497748       0.276068
# 128            0.575404           1.393093       -0.497748       0.573768
# 407            0.532429          -1.057618       -0.497748       1.085668
#
#      capital-loss  incident_hour_of_the_day  number_of_vehicles_involved  \
# 991     -0.194098                  1.352635                    -0.801572
# 90       0.950248                  0.053135                     0.187209
# 983     -1.921280                 -0.380031                    -0.801572
# 128     -0.730733                  1.497024                    -0.801572
# 407     -1.327783                 -0.957587                     1.175991
#
#      bodily_injuries  witnesses  injury_claim  ...  \
# ...

# %% [markdown]
# Modelling

# %% [markdown]
# Support Vector classifier

# %%
from sklearn.svm import SVC
svc_model= SVC()
svc_model.fit(X_train,y_train)

y_pred= svc_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

svc_model_train_acc = accuracy_score(y_train, svc_model.predict(X_train))
svc_model_test_acc = accuracy_score(y_test, y_pred)

print("Training acuracy : ", svc_model_train_acc)
print("testing acuracy ", svc_model_test_acc)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Training acuracy :  0.8586666666666667
# testing acuracy  0.772
# [[193   0]
#  [ 57   0]]
#               precision    recall  f1-score   support
#
#            N       0.77      1.00      0.87       193
#            Y       0.00      0.00      0.00        57
#
#     accuracy                           0.77       250
#    macro avg       0.39      0.50      0.44       250
# weighted avg       0.60      0.77      0.67       250

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_model = KNeighborsClassifier(n_neighbors=30)
knn_model.fit(X_train, y_train)

y_pred=knn_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

knn_model_train_acc = accuracy_score(y_train, knn_model.predict(X_train))
knn_model_test_acc = accuracy_score(y_test, y_pred)

print("Training acuracy : ", knn_model_train_acc)
print("testing acuracy ", knn_model_test_acc)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Training acuracy :  0.7493333333333333
# testing acuracy  0.772
# [[193   0]
#  [ 57   0]]
#               precision    recall  f1-score   support
#
#            N       0.77      1.00      0.87       193
#            Y       0.00      0.00      0.00        57
#
#     accuracy                           0.77       250
#    macro avg       0.39      0.50      0.44       250
# weighted avg       0.60      0.77      0.67       250

# %% [markdown]
# Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

decision_tree_model= DecisionTreeClassifier()
decision_tree_model.fit(X_train,y_train)

y_pred= decision_tree_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

decision_tree_model_train_acc = accuracy_score(y_train, decision_tree_model.predict(X_train))
decision_tree_model_test_acc = accuracy_score(y_test, y_pred)

print("Training acuracy : ", decision_tree_model_train_acc)
print("testing acuracy ", decision_tree_model_test_acc)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Training acuracy :  1.0
# testing acuracy  0.412
# [[ 72 121]
#  [ 26  31]]
#               precision    recall  f1-score   support
#
#            N       0.73      0.37      0.49       193
#            Y       0.20      0.54      0.30        57
#
#     accuracy                           0.41       250
#    macro avg       0.47      0.46      0.40       250
# weighted avg       0.61      0.41      0.45       250

# %%
from sklearn.model_selection import GridSearchCV

grid_params= {
    'criterion' :['gini', 'entropy'],
    'max_depth': [3,5,7,10],
    'min_samples_split': range(2,10,1),
    'min_samples_leaf': range(2,10,1)
    }

grid_search= GridSearchCV(decision_tree_model, grid_params,cv=5, n_jobs=-1, verbose=1)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 512 candidates, totalling 2560 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 7, 10],
#                          'min_samples_leaf': range(2, 10),
#                          'min_samples_split': range(2, 10)},
#              verbose=1)

# %%
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'criterion': 'gini', 'max_depth': 3, 'min_samples_leaf': 7, 'min_samples_split': 2}
# 0.8093333333333333

# %%
decision_tree_model= grid_search.best_estimator_
y_pred= decision_tree_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

decision_tree_model_train_acc = accuracy_score(y_train, decision_tree_model.predict(X_train))
decision_tree_model_test_acc = accuracy_score(y_test, y_pred)

print(f"Training acuracy of dd  : {decision_tree_model_train_acc}")
print(f"testing acuracy of dd: { decision_tree_model_test_acc}")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Training acuracy of dd  : 0.816
# testing acuracy of dd: 0.808
# [[166  27]
#  [ 21  36]]
#               precision    recall  f1-score   support
#
#            N       0.89      0.86      0.87       193
#            Y       0.57      0.63      0.60        57
#
#     accuracy                           0.81       250
#    macro avg       0.73      0.75      0.74       250
# weighted avg       0.82      0.81      0.81       250

# %% [markdown]
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(criterion='entropy', max_depth=15,max_features='sqrt',min_samples_leaf=1,min_samples_split=3,n_estimators=14)
rf_model.fit(X_train,y_train)

y_pred= rf_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

rf_model_train_acc = accuracy_score(y_train, rf_model.predict(X_train))
rf_model_test_acc = accuracy_score(y_test, y_pred)

print("Training acuracy : ", rf_model_train_acc)
print("testing acuracy ", rf_model_test_acc)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Training acuracy :  0.98
# testing acuracy  0.628
# [[120  73]
#  [ 20  37]]
#               precision    recall  f1-score   support
#
#            N       0.86      0.62      0.72       193
#            Y       0.34      0.65      0.44        57
#
#     accuracy                           0.63       250
#    macro avg       0.60      0.64      0.58       250
# weighted avg       0.74      0.63      0.66       250

# %% [markdown]
# Ada Boost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier

ada_model = AdaBoostClassifier(estimator=decision_tree_model)
parameters = {
    'n_estimators': [50,70,90,120,180,200],
    'learning_rate': [0.001,0.01,0.1,1,10],
    'algorithm' : ['SAMME','SAMME.R']
}

grid_search= GridSearchCV(ada_model, parameters, n_jobs=-1, cv=5, verbose=1)
grid_search.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# GridSearchCV(cv=5,
#              estimator=AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=3,
#                                                                            min_samples_leaf=7)),
#              n_jobs=-1,
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.001, 0.01, 0.1, 1, 10],
#                          'n_estimators': [50, 70, 90, 120, 180, 200]},
#              verbose=1)

# %%
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'algorithm': 'SAMME', 'learning_rate': 0.001, 'n_estimators': 50}
# 0.8093333333333333

# %%
ada_model= grid_search.best_estimator_
y_pred= ada_model.predict((X_test))

# %%
ada_train_acc= accuracy_score(y_train, ada_model.predict(X_train))
ada_test_acc= accuracy_score(y_test,y_pred)

print(f"Training acuracy of ada boost  : {ada_train_acc}")
print(f"testing acuracy of ada boost: { ada_test_acc}")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Training acuracy of ada boost  : 0.816
# testing acuracy of ada boost: 0.808
# [[166  27]
#  [ 21  36]]
#               precision    recall  f1-score   support
#
#            N       0.89      0.86      0.87       193
#            Y       0.57      0.63      0.60        57
#
#     accuracy                           0.81       250
#    macro avg       0.73      0.75      0.74       250
# weighted avg       0.82      0.81      0.81       250

# %% [markdown]
# Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb= GradientBoostingClassifier()
gb.fit(X_train,y_train)

gb_acc= accuracy_score(y_test, gb.predict(X_test))
print(f"Training acuracy of gradient boosting is   : {accuracy_score(y_train, gb.predict(X_train))}")
print(f"testing acuracy of gradient boosting classifier is: {gb_acc}\n")
print(f"confusion matrix: - \n { confusion_matrix(y_test,gb.predict(X_test))}\n")
print(f"classification report : - \n { classification_report(y_test,gb.predict(X_test))}")
# Out:
# Training acuracy of gradient boosting is   : 0.92
# testing acuracy of gradient boosting classifier is: 0.672
#
# confusion matrix: -
#  [[145  48]
#  [ 34  23]]
#
# classification report : -
#                precision    recall  f1-score   support
#
#            N       0.81      0.75      0.78       193
#            Y       0.32      0.40      0.36        57
#
#     accuracy                           0.67       250
#    macro avg       0.57      0.58      0.57       250
# weighted avg       0.70      0.67      0.68       250

# %% [markdown]
# Stochastic Gradient boosting

# %%
sgb= GradientBoostingClassifier(subsample=0.90, max_features=0.70)
sgb.fit(X_train, y_train)

sgb_acc= accuracy_score(y_test, sgb.predict(X_test))

print(f"Training acuracy of stochastic gradient boosting is   : {accuracy_score(y_train, sgb.predict(X_train))}")
print(f"testing acuracy of stochastic gradient boosting classifier is: {sgb_acc}\n")

print(f"confusion matrix: - \n { confusion_matrix(y_test,sgb.predict(X_test))}\n")
print(f"classification report : - \n { classification_report(y_test,sgb.predict(X_test))}")
# Out:
# Training acuracy of stochastic gradient boosting is   : 0.9306666666666666
# testing acuracy of stochastic gradient boosting classifier is: 0.476
#
# confusion matrix: -
#  [[ 71 122]
#  [  9  48]]
#
# classification report : -
#                precision    recall  f1-score   support
#
#            N       0.89      0.37      0.52       193
#            Y       0.28      0.84      0.42        57
#
#     accuracy                           0.48       250
#    macro avg       0.58      0.60      0.47       250
# weighted avg       0.75      0.48      0.50       250

# %% [markdown]
# XgBoost Classifier

# %%
from sklearn.preprocessing import LabelEncoder

le= LabelEncoder()
y_train= le.fit_transform(y_train)

# %%
y_test=le.fit_transform(y_test)

# %%
from xgboost import XGBClassifier 

xgb= XGBClassifier()
xgb.fit(X_train, y_train)

y_pred= xgb.predict(X_test)

# %%
xgb_train_acc = accuracy_score(y_train, xgb.predict(X_train))
xgb_test_acc= accuracy_score(y_test, y_pred)

print(f"Training acuracy of xgboost is   : {xgb_train_acc}")
print(f"testing acuracy of xgboost is: {xgb_test_acc}")

print(confusion_matrix(y_test, y_pred))
print(classification_report (y_test,y_pred))
# Out:
# Training acuracy of xgboost is   : 1.0
# testing acuracy of xgboost is: 0.676
# [[138  55]
#  [ 26  31]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.72      0.77       193
#            1       0.36      0.54      0.43        57
#
#     accuracy                           0.68       250
#    macro avg       0.60      0.63      0.60       250
# weighted avg       0.73      0.68      0.70       250

# %%
param_grid= {"n_estimators": [10,50,100,130], "criterion": [ ' gini', ' entropy'], "max_depth": range(2,10,1)}

grid= GridSearchCV(estimator=xgb, param_grid=param_grid, cv=5, verbose=3,n_jobs=-1)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# GridSearchCV(cv=5,
#              estimator=AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=3,
#                                                                            min_samples_leaf=7)),
#              n_jobs=-1,
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.001, 0.01, 0.1, 1, 10],
#                          'n_estimators': [50, 70, 90, 120, 180, 200]},
#              verbose=1)

# %%
xgb= grid_search.best_estimator_
y_pred= xgb.predict(X_test)

# %%
xgb_train_acc = accuracy_score(y_train, xgb.predict(X_train))
xgb_test_acc= accuracy_score(y_test, y_pred)

print(f"Training acuracy of xgboost is   : {xgb_train_acc}")
print(f"testing acuracy of xgboost is: {xgb_test_acc}")

print(confusion_matrix(y_test, y_pred))
print(classification_report (y_test,y_pred))
# Out:
# Training acuracy of xgboost is   : 0.816
# testing acuracy of xgboost is: 0.808
# [[166  27]
#  [ 21  36]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.87       193
#            1       0.57      0.63      0.60        57
#
#     accuracy                           0.81       250
#    macro avg       0.73      0.75      0.74       250
# weighted avg       0.82      0.81      0.81       250

# %% [markdown]
# extra trees classifier

# %%
from sklearn.ensemble import ExtraTreesClassifier

etc=ExtraTreesClassifier()
etc.fit(X_train,y_train)

etc_acc= accuracy_score(y_test, etc.predict(X_test))

print(f"Training acuracy of extra trees classifier is   : {accuracy_score(y_train, etc.predict(X_train))}")
print(f"testing acuracy of extra trees classifier is: {etc_acc}\n")

print(f"confusion matrix: - \n { confusion_matrix(y_test,etc.predict(X_test))}\n")
print(f"classification report : - \n { classification_report(y_test,etc.predict(X_test))}")
# Out:
# Training acuracy of extra trees classifier is   : 1.0
# testing acuracy of extra trees classifier is: 0.784
#
# confusion matrix: -
#  [[172  21]
#  [ 33  24]]
#
# classification report : -
#                precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86       193
#            1       0.53      0.42      0.47        57
#
#     accuracy                           0.78       250
#    macro avg       0.69      0.66      0.67       250
# weighted avg       0.77      0.78      0.77       250

# %% [markdown]
# voting classifier

# %%
from sklearn.ensemble import VotingClassifier

classifiers = [
    ('Support Vector Classifier', svc_model), 
    ('knn_model', knn_model), 
    ('Decision Tree', decision_tree_model), 
    ('Random Forest', rf_model), 
    ('Ada Boost', ada_model), 
    ('XGBoost', xgb), 
    ('Gradient Boosting Classifier', gb), 
    ('SGD', sgb), 
    ('Extra Trees Classifier', etc)
]

vc = VotingClassifier(estimators=classifiers)

vc.fit(X_train, y_train)

y_pred = vc.predict(X_test)

# %%
vc_train_acc = accuracy_score(y_train, vc.predict(X_train))
vc_test_acc = accuracy_score(y_test, y_pred)

print(f"Training accuracy of Voting Classifier is : {vc_train_acc}")
print(f"Test accuracy of Voting Classifier is : {vc_test_acc}")

print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Training accuracy of Voting Classifier is : 0.9266666666666666
# Test accuracy of Voting Classifier is : 0.788
# [[174  19]
#  [ 34  23]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87       193
#            1       0.55      0.40      0.46        57
#
#     accuracy                           0.79       250
#    macro avg       0.69      0.65      0.67       250
# weighted avg       0.77      0.79      0.78       250

# %% [markdown]
# Models comparison

# %%
models = pd.DataFrame({
    'Model': ['svc_model', 'knn_model', 'Decision Tree', 'Random Forest', 'Ada Boost', 'Gradient Boost', 'SGB', 'Extra Trees', 'XgBoost'],
    'Score': [svc_model_test_acc, knn_model_test_acc, decision_tree_model_test_acc, rf_model_test_acc, ada_test_acc, gb_acc, sgb_acc, etc_acc, xgb_test_acc]
})

models.sort_values(by='Score', ascending=False)
# Out:
#             Model  Score
# 2   Decision Tree  0.808
# 8         XgBoost  0.808
# 4       Ada Boost  0.808
# 7     Extra Trees  0.784
# 0       svc_model  0.772
# 1       knn_model  0.772
# 5  Gradient Boost  0.672
# 3   Random Forest  0.628
# 6             SGB  0.476

# %%
plt.bar(models['Model'], models['Score'], width=0.4, color= 'maroon')
plt.xlabel("Models")
plt.xticks(rotation=90)
plt.ylabel("Scores")
plt.title("Models for Insurance Fraud detection ")
plt.show()
